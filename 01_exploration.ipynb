# %% [markdown]
# # Exploration Notebook
#
# Placeholder notebook for initial data exploration in this course's business analytics portfolio project.

# %%
import pandas as pd
import numpy as np

print('Environment is set up and working.')
